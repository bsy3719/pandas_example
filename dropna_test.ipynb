# %%
import pandas as pd

# %%
df = pd.read_csv("./data/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def dropna(df, cols: list):
    # df.dropna(subset = ["Sex", "Cabin"], thresh=2400, how='any')
    """
    name : 결측치 제거
    outputType : none
    comment : 결측치 제거 함수, 꼭 1개의 인자를 넣어주세요
    """
    return df.dropna(subset=cols)

# %%
cols = ["Age", "Fare"]
df.dropna(subset=cols)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test = "targerCol(column) = 빈값을 채울 대상 컬럼, groupByCol(column) = 그룹핑할 컬럼"

# %%
list(map(lambda x: x.strip().replace("=",":"), test.split(",")))
# Out:
# ['targerCol(column) : 빈값을 채울 대상 컬럼', 'groupByCol(column) : 그룹핑할 컬럼']

# %%
bins = [9, 16, 25, 35, 60]
labels = [1, 2, 3, 4]
new = pd.cut(df["Age"], bins=bins, labels=labels)

# %%
pd.get_dummies(df["Sex"])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
bins = '[9, 16, 25, 35, 60]'
# Out:
# ['[',
#  '9',
#  ',',
#  ' ',
#  '1',
#  '6',
#  ',',
#  ' ',
#  '2',
#  '5',
#  ',',
#  ' ',
#  '3',
#  '5',
#  ',',
#  ' ',
#  '6',
#  '0',
#  ']']

# %%
parameter_list = ['Age', "[9, 16, 25, 35, 60]", "['Age', 'Sex', 'Cabin']"]
x = ""

try:
    print(list(map(list, parameter_list)))
except:
    pass
# Out:
# [['A', 'g', 'e'], ['[', '9', ',', ' ', '1', '6', ',', ' ', '2', '5', ',', ' ', '3', '5', ',', ' ', '6', '0', ']'], ['[', "'", 'A', 'g', 'e', "'", ',', ' ', "'", 'S', 'e', 'x', "'", ',', ' ', "'", 'C', 'a', 'b', 'i', 'n', "'", ']']]

# %%
for param in parameter_list:
    if type(param) == str:
        x += "'{}',".format(param)
    else:
        x += "{},".format(param)
        
x = "df, " + x[:-1]

# %%
x
# Out:
# "df, 'Age','[9, 16, 25, 35, 60]','['Age', 'Sex', 'Cabin']'"

# %%
for param in parameter_list:
    print(type(param))
    if type(param) == str:
        print(param)
# Out:
# <class 'str'>
# Age
# <class 'list'>
# <class 'list'>
