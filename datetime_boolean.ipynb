# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/baek/Downloads/data.csv")

# %%
df
# Out:
#      trip_id  year  month  week  day  hour    usertype  gender  \
# 0    2355134  2014      6    27    0    23  Subscriber    Male
# 1    2355133  2014      6    27    0    23  Subscriber    Male
# 2    2355130  2014      6    27    0    23  Subscriber    Male
# 3    2355129  2014      6    27    0    23  Subscriber  Female
# 4    2355128  2014      6    27    0    23  Subscriber  Female
# ..       ...   ...    ...   ...  ...   ...         ...     ...
# 173  2354629  2014      6    27    0    19  Subscriber  Female
# 174  2354627  2014      6    27    0    19  Subscriber    Male
# 175  2354626  2014      6    27    0    19  Subscriber    Male
# 176  2354625  2014      6    27    0    19  Subscriber    Male
# 177  2354624  2014      6    27    0    19  Subscriber  Female
#
#            starttime         stoptime  ...  from_station_id  \
# 0    2014.6.30 23:57    2014.7.1 0:07  ...              131
# 1    2014.6.30 23:56    2014.7.1 0:00  ...              282
# ...

# %%
df.dtypes
# Out:
# trip_id                int64
# year                   int64
# month                  int64
# week                   int64
# day                    int64
# hour                   int64
# usertype              object
# gender                object
# starttime             object
# stoptime              object
# tripduration         float64
# temperature            int64
# events                object
# from_station_id        int64
# from_station_name     object
# latitude_start       float64
# longitude_start      float64
# dpcapacity_start       int64
# to_station_id          int64
# to_station_name       object
# latitude_end         float64
# longitude_end        float64
# dpcapacity_end         int64
# dtype: object

# %%
df = df.astype({"starttime": "datetime64"})

# %%
df.dtypes
# Out:
# trip_id                       int64
# year                          int64
# month                         int64
# week                          int64
# day                           int64
# hour                          int64
# usertype                     object
# gender                       object
# starttime            datetime64[ns]
# stoptime                     object
# tripduration                float64
# temperature                   int64
# events                       object
# from_station_id               int64
# from_station_name            object
# latitude_start              float64
# longitude_start             float64
# dpcapacity_start              int64
# to_station_id                 int64
# to_station_name              object
# latitude_end                float64
# longitude_end               float64
# dpcapacity_end                int64
# dtype: object

# %%
df["month"] = df["month"].astype("bool")
